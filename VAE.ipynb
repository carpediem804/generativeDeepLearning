# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import sys 
sys.path.append('/content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/utils')
sys.path.append('/content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/models')

# %%
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/utils',
#  '/content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/models']

# %%
import os
import loaders
import VAE
# Out:
# Using TensorFlow backend.

# %%
PATH = '/content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/'
os.path.join(PATH)
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/'

# %%
## 실행 매개변수  ## 저장될 위치랑 이런것들 
SECTION = 'vae'
RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = PATH
RUN_FOLDER += 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

mode =  'load' #'load' #

# %%
##mnist 데이터 가져오깅 ~ 
(x_train, y_train), (x_test, y_test) = loaders.load_mnist()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
##VAE에 있는 이미 선언된애 가져다가 쓰기 
vae = VAE.VariationalAutoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
)

if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
vae.encoder.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 7, 7, 64)     0           encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 3136)         0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 2)            6274        flatten_1[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 2)            6274        flatten_1[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(vae.encoder, to_file='vae_encoder.png', show_shapes = True, show_layer_names = True)

# %%
vae.decoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(vae.decoder, to_file='vae_decoder.png', show_shapes = True, show_layer_names = True)

# %%
## VAE 훈련 해봅시다 
LEARNING_RATE = 0.0005
R_LOSS_FACTOR = 1000 ##DECODER 손실값에 가중치 주는거

# %%
vae.compile(LEARNING_RATE, R_LOSS_FACTOR)

# %%
BATCH_SIZE = 32
EPOCHS = 200
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

# %%
vae.train(     
    x_train
    , batch_size = BATCH_SIZE
    , epochs = EPOCHS
    , run_folder = RUN_FOLDER
    , print_every_n_batches = PRINT_EVERY_N_BATCHES
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# Epoch 1/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 58.7089 - vae_r_loss: 55.4996 - vae_kl_loss: 3.2092
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-001-58.71.h5
#
# Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 2/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 51.8797 - vae_r_loss: 48.0067 - vae_kl_loss: 3.8731
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-002-51.88.h5
#
# Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 3/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 50.5251 - vae_r_loss: 46.3703 - vae_kl_loss: 4.1548
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-003-50.53.h5
#
# Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 4/200
# 60000/60000 [==============================] - 212s 4ms/step - loss: 49.5835 - vae_r_loss: 45.2305 - vae_kl_loss: 4.3530
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-004-49.58.h5
#
# Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 5/200
# 60000/60000 [==============================] - 210s 3ms/step - loss: 48.9549 - vae_r_loss: 44.4613 - vae_kl_loss: 4.4936
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-005-48.95.h5
#
# Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 6/200
# 60000/60000 [==============================] - 209s 3ms/step - loss: 48.4636 - vae_r_loss: 43.8782 - vae_kl_loss: 4.5855
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-006-48.46.h5
#
# Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 7/200
# 60000/60000 [==============================] - 206s 3ms/step - loss: 48.1280 - vae_r_loss: 43.4603 - vae_kl_loss: 4.6677
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-007-48.13.h5
#
# Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 8/200
# 60000/60000 [==============================] - 206s 3ms/step - loss: 47.7774 - vae_r_loss: 43.0581 - vae_kl_loss: 4.7193
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-008-47.78.h5
#
# Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 9/200
# 60000/60000 [==============================] - 203s 3ms/step - loss: 47.5421 - vae_r_loss: 42.7757 - vae_kl_loss: 4.7665
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-009-47.54.h5
#
# Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 10/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 47.3732 - vae_r_loss: 42.5698 - vae_kl_loss: 4.8033
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-010-47.37.h5
#
# Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 11/200
# 60000/60000 [==============================] - 220s 4ms/step - loss: 47.1909 - vae_r_loss: 42.3360 - vae_kl_loss: 4.8549
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-011-47.19.h5
#
# Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 12/200
# 60000/60000 [==============================] - 204s 3ms/step - loss: 46.9948 - vae_r_loss: 42.1218 - vae_kl_loss: 4.8729
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-012-46.99.h5
#
# Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 13/200
# 60000/60000 [==============================] - 205s 3ms/step - loss: 46.8400 - vae_r_loss: 41.9292 - vae_kl_loss: 4.9108
#
# Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-013-46.84.h5
#
# Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 14/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 46.6842 - vae_r_loss: 41.7451 - vae_kl_loss: 4.9391
#
# Epoch 00014: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-014-46.68.h5
#
# Epoch 00014: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 15/200
# 60000/60000 [==============================] - 216s 4ms/step - loss: 46.5624 - vae_r_loss: 41.6093 - vae_kl_loss: 4.9531
#
# Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-015-46.56.h5
#
# Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 16/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 46.4862 - vae_r_loss: 41.5030 - vae_kl_loss: 4.9833
#
# Epoch 00016: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-016-46.49.h5
#
# Epoch 00016: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 17/200
# 60000/60000 [==============================] - 221s 4ms/step - loss: 46.3456 - vae_r_loss: 41.3284 - vae_kl_loss: 5.0172
#
# Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-017-46.35.h5
#
# Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 18/200
# 60000/60000 [==============================] - 224s 4ms/step - loss: 46.2863 - vae_r_loss: 41.2598 - vae_kl_loss: 5.0265
#
# Epoch 00018: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-018-46.29.h5
#
# Epoch 00018: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 19/200
# 60000/60000 [==============================] - 221s 4ms/step - loss: 46.1591 - vae_r_loss: 41.1218 - vae_kl_loss: 5.0373
#
# Epoch 00019: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-019-46.16.h5
#
# Epoch 00019: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 20/200
# 60000/60000 [==============================] - 224s 4ms/step - loss: 46.0808 - vae_r_loss: 41.0364 - vae_kl_loss: 5.0444
#
# Epoch 00020: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-020-46.08.h5
#
# Epoch 00020: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 21/200
# 60000/60000 [==============================] - 223s 4ms/step - loss: 46.0056 - vae_r_loss: 40.9373 - vae_kl_loss: 5.0684
#
# Epoch 00021: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-021-46.01.h5
#
# Epoch 00021: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 22/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 45.9018 - vae_r_loss: 40.8187 - vae_kl_loss: 5.0831
#
# Epoch 00022: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-022-45.90.h5
#
# Epoch 00022: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 23/200
# 60000/60000 [==============================] - 211s 4ms/step - loss: 45.8439 - vae_r_loss: 40.7507 - vae_kl_loss: 5.0932
#
# Epoch 00023: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-023-45.84.h5
#
# Epoch 00023: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 24/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 45.7502 - vae_r_loss: 40.6335 - vae_kl_loss: 5.1167
#
# Epoch 00024: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-024-45.75.h5
#
# Epoch 00024: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 25/200
# 60000/60000 [==============================] - 214s 4ms/step - loss: 45.7030 - vae_r_loss: 40.5906 - vae_kl_loss: 5.1125
#
# Epoch 00025: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-025-45.70.h5
#
# Epoch 00025: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 26/200
# 60000/60000 [==============================] - 210s 3ms/step - loss: 45.6486 - vae_r_loss: 40.5159 - vae_kl_loss: 5.1327
#
# Epoch 00026: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-026-45.65.h5
#
# Epoch 00026: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 27/200
# 60000/60000 [==============================] - 214s 4ms/step - loss: 45.6258 - vae_r_loss: 40.4785 - vae_kl_loss: 5.1472
#
# Epoch 00027: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-027-45.63.h5
#
# Epoch 00027: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 28/200
# 60000/60000 [==============================] - 206s 3ms/step - loss: 45.5060 - vae_r_loss: 40.3611 - vae_kl_loss: 5.1450
#
# Epoch 00028: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-028-45.51.h5
#
# Epoch 00028: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 29/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 45.4662 - vae_r_loss: 40.3060 - vae_kl_loss: 5.1603
#
# Epoch 00029: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-029-45.47.h5
#
# Epoch 00029: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 30/200
# 60000/60000 [==============================] - 221s 4ms/step - loss: 45.4254 - vae_r_loss: 40.2415 - vae_kl_loss: 5.1838
#
# Epoch 00030: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-030-45.43.h5
#
# Epoch 00030: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 31/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 45.3879 - vae_r_loss: 40.2200 - vae_kl_loss: 5.1679
#
# Epoch 00031: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-031-45.39.h5
#
# Epoch 00031: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 32/200
# 60000/60000 [==============================] - 224s 4ms/step - loss: 45.3386 - vae_r_loss: 40.1472 - vae_kl_loss: 5.1914
#
# Epoch 00032: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-032-45.34.h5
#
# Epoch 00032: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 33/200
# 60000/60000 [==============================] - 229s 4ms/step - loss: 45.2942 - vae_r_loss: 40.0900 - vae_kl_loss: 5.2042
#
# Epoch 00033: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-033-45.29.h5
#
# Epoch 00033: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 34/200
# 60000/60000 [==============================] - 230s 4ms/step - loss: 45.2540 - vae_r_loss: 40.0582 - vae_kl_loss: 5.1958
#
# Epoch 00034: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-034-45.25.h5
#
# Epoch 00034: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 35/200
# 60000/60000 [==============================] - 221s 4ms/step - loss: 45.2359 - vae_r_loss: 40.0198 - vae_kl_loss: 5.2161
#
# Epoch 00035: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-035-45.24.h5
#
# Epoch 00035: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 36/200
# 60000/60000 [==============================] - 222s 4ms/step - loss: 45.1609 - vae_r_loss: 39.9354 - vae_kl_loss: 5.2255
#
# Epoch 00036: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-036-45.16.h5
#
# Epoch 00036: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 37/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 45.1278 - vae_r_loss: 39.8905 - vae_kl_loss: 5.2373
#
# Epoch 00037: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-037-45.13.h5
#
# Epoch 00037: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 38/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 45.1161 - vae_r_loss: 39.8814 - vae_kl_loss: 5.2348
#
# Epoch 00038: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-038-45.12.h5
#
# Epoch 00038: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 39/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 45.0365 - vae_r_loss: 39.7935 - vae_kl_loss: 5.2429
#
# Epoch 00039: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-039-45.04.h5
#
# Epoch 00039: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 40/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 45.0074 - vae_r_loss: 39.7550 - vae_kl_loss: 5.2524
#
# Epoch 00040: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-040-45.01.h5
#
# Epoch 00040: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 41/200
# 60000/60000 [==============================] - 223s 4ms/step - loss: 45.0126 - vae_r_loss: 39.7624 - vae_kl_loss: 5.2501
#
# Epoch 00041: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-041-45.01.h5
#
# Epoch 00041: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 42/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 44.9153 - vae_r_loss: 39.6562 - vae_kl_loss: 5.2592
#
# Epoch 00042: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-042-44.92.h5
#
# Epoch 00042: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 43/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 44.9258 - vae_r_loss: 39.6548 - vae_kl_loss: 5.2710
#
# Epoch 00043: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-043-44.93.h5
#
# Epoch 00043: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 44/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 44.9055 - vae_r_loss: 39.6395 - vae_kl_loss: 5.2660
#
# Epoch 00044: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-044-44.91.h5
#
# Epoch 00044: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 45/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 44.8692 - vae_r_loss: 39.5983 - vae_kl_loss: 5.2709
#
# Epoch 00045: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-045-44.87.h5
#
# Epoch 00045: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 46/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 44.8591 - vae_r_loss: 39.5814 - vae_kl_loss: 5.2778
#
# Epoch 00046: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-046-44.86.h5
#
# Epoch 00046: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 47/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 44.8072 - vae_r_loss: 39.5142 - vae_kl_loss: 5.2929
#
# Epoch 00047: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-047-44.81.h5
#
# Epoch 00047: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 48/200
# 60000/60000 [==============================] - 216s 4ms/step - loss: 44.7720 - vae_r_loss: 39.4800 - vae_kl_loss: 5.2920
#
# Epoch 00048: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-048-44.77.h5
#
# Epoch 00048: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 49/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 44.7097 - vae_r_loss: 39.4123 - vae_kl_loss: 5.2973
#
# Epoch 00049: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-049-44.71.h5
#
# Epoch 00049: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 50/200
# 60000/60000 [==============================] - 209s 3ms/step - loss: 44.7465 - vae_r_loss: 39.4344 - vae_kl_loss: 5.3121
#
# Epoch 00050: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-050-44.75.h5
#
# Epoch 00050: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 51/200
# 60000/60000 [==============================] - 210s 3ms/step - loss: 44.6740 - vae_r_loss: 39.3615 - vae_kl_loss: 5.3126
#
# Epoch 00051: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-051-44.67.h5
#
# Epoch 00051: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 52/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 44.7257 - vae_r_loss: 39.4095 - vae_kl_loss: 5.3162
#
# Epoch 00052: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-052-44.73.h5
#
# Epoch 00052: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 53/200
# 60000/60000 [==============================] - 212s 4ms/step - loss: 44.6801 - vae_r_loss: 39.3635 - vae_kl_loss: 5.3166
#
# Epoch 00053: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-053-44.68.h5
#
# Epoch 00053: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 54/200
# 60000/60000 [==============================] - 210s 4ms/step - loss: 44.6328 - vae_r_loss: 39.3046 - vae_kl_loss: 5.3282
#
# Epoch 00054: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-054-44.63.h5
#
# Epoch 00054: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 55/200
# 60000/60000 [==============================] - 211s 4ms/step - loss: 44.5916 - vae_r_loss: 39.2782 - vae_kl_loss: 5.3134
#
# Epoch 00055: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-055-44.59.h5
#
# Epoch 00055: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 56/200
# 60000/60000 [==============================] - 207s 3ms/step - loss: 44.5685 - vae_r_loss: 39.2522 - vae_kl_loss: 5.3163
#
# Epoch 00056: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-056-44.57.h5
#
# Epoch 00056: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 57/200
# 60000/60000 [==============================] - 210s 3ms/step - loss: 44.5640 - vae_r_loss: 39.2242 - vae_kl_loss: 5.3398
#
# Epoch 00057: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-057-44.56.h5
#
# Epoch 00057: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 58/200
# 60000/60000 [==============================] - 209s 3ms/step - loss: 44.5248 - vae_r_loss: 39.1983 - vae_kl_loss: 5.3265
#
# Epoch 00058: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-058-44.52.h5
#
# Epoch 00058: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 59/200
# 60000/60000 [==============================] - 206s 3ms/step - loss: 44.5340 - vae_r_loss: 39.1938 - vae_kl_loss: 5.3402
#
# Epoch 00059: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-059-44.53.h5
#
# Epoch 00059: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 60/200
# 60000/60000 [==============================] - 204s 3ms/step - loss: 44.5003 - vae_r_loss: 39.1539 - vae_kl_loss: 5.3463
#
# Epoch 00060: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-060-44.50.h5
#
# Epoch 00060: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 61/200
# 60000/60000 [==============================] - 206s 3ms/step - loss: 44.5043 - vae_r_loss: 39.1664 - vae_kl_loss: 5.3378
#
# Epoch 00061: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-061-44.50.h5
#
# Epoch 00061: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 62/200
# 60000/60000 [==============================] - 208s 3ms/step - loss: 44.5026 - vae_r_loss: 39.1345 - vae_kl_loss: 5.3682
#
# Epoch 00062: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-062-44.50.h5
#
# Epoch 00062: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 63/200
# 60000/60000 [==============================] - 209s 3ms/step - loss: 44.4965 - vae_r_loss: 39.1364 - vae_kl_loss: 5.3601
#
# Epoch 00063: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-063-44.50.h5
#
# Epoch 00063: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 64/200
# 60000/60000 [==============================] - 220s 4ms/step - loss: 44.4386 - vae_r_loss: 39.0689 - vae_kl_loss: 5.3697
#
# Epoch 00064: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-064-44.44.h5
#
# Epoch 00064: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 65/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 44.4049 - vae_r_loss: 39.0447 - vae_kl_loss: 5.3601
#
# Epoch 00065: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-065-44.40.h5
#
# Epoch 00065: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 66/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 44.4290 - vae_r_loss: 39.0670 - vae_kl_loss: 5.3619
#
# Epoch 00066: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-066-44.43.h5
#
# Epoch 00066: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 67/200
# 60000/60000 [==============================] - 225s 4ms/step - loss: 44.3908 - vae_r_loss: 39.0098 - vae_kl_loss: 5.3810
#
# Epoch 00067: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-067-44.39.h5
#
# Epoch 00067: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 68/200
# 60000/60000 [==============================] - 221s 4ms/step - loss: 44.3794 - vae_r_loss: 39.0077 - vae_kl_loss: 5.3717
#
# Epoch 00068: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-068-44.38.h5
#
# Epoch 00068: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 69/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 44.3270 - vae_r_loss: 38.9512 - vae_kl_loss: 5.3759
#
# Epoch 00069: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-069-44.33.h5
#
# Epoch 00069: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 70/200
# 60000/60000 [==============================] - 220s 4ms/step - loss: 44.2875 - vae_r_loss: 38.9137 - vae_kl_loss: 5.3737
#
# Epoch 00070: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-070-44.29.h5
#
# Epoch 00070: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 71/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 44.2967 - vae_r_loss: 38.9080 - vae_kl_loss: 5.3887
#
# Epoch 00071: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-071-44.30.h5
#
# Epoch 00071: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 72/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 44.2930 - vae_r_loss: 38.8935 - vae_kl_loss: 5.3994
#
# Epoch 00072: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-072-44.29.h5
#
# Epoch 00072: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 73/200
# 60000/60000 [==============================] - 232s 4ms/step - loss: 44.2532 - vae_r_loss: 38.8562 - vae_kl_loss: 5.3970
#
# Epoch 00073: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-073-44.25.h5
#
# Epoch 00073: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 74/200
# 60000/60000 [==============================] - 222s 4ms/step - loss: 44.2439 - vae_r_loss: 38.8433 - vae_kl_loss: 5.4006
#
# Epoch 00074: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-074-44.24.h5
#
# Epoch 00074: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 75/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 44.2511 - vae_r_loss: 38.8444 - vae_kl_loss: 5.4067
#
# Epoch 00075: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-075-44.25.h5
#
# Epoch 00075: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 76/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 44.2251 - vae_r_loss: 38.8320 - vae_kl_loss: 5.3931
#
# Epoch 00076: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-076-44.23.h5
#
# Epoch 00076: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 77/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 44.2100 - vae_r_loss: 38.7989 - vae_kl_loss: 5.4110
#
# Epoch 00077: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-077-44.21.h5
#
# Epoch 00077: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 78/200
# 60000/60000 [==============================] - 216s 4ms/step - loss: 44.1785 - vae_r_loss: 38.7749 - vae_kl_loss: 5.4037
#
# Epoch 00078: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-078-44.18.h5
#
# Epoch 00078: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 79/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 44.2572 - vae_r_loss: 38.8506 - vae_kl_loss: 5.4066
#
# Epoch 00079: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-079-44.26.h5
#
# Epoch 00079: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 80/200
# 60000/60000 [==============================] - 209s 3ms/step - loss: 44.1946 - vae_r_loss: 38.7646 - vae_kl_loss: 5.4300
#
# Epoch 00080: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-080-44.19.h5
#
# Epoch 00080: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 81/200
# 60000/60000 [==============================] - 210s 3ms/step - loss: 44.1526 - vae_r_loss: 38.7377 - vae_kl_loss: 5.4149
#
# Epoch 00081: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-081-44.15.h5
#
# Epoch 00081: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 82/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 44.1054 - vae_r_loss: 38.6837 - vae_kl_loss: 5.4217
#
# Epoch 00082: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-082-44.11.h5
#
# Epoch 00082: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 83/200
# 60000/60000 [==============================] - 211s 4ms/step - loss: 44.1766 - vae_r_loss: 38.7573 - vae_kl_loss: 5.4194
#
# Epoch 00083: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-083-44.18.h5
#
# Epoch 00083: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 84/200
# 60000/60000 [==============================] - 209s 3ms/step - loss: 44.0956 - vae_r_loss: 38.6750 - vae_kl_loss: 5.4206
#
# Epoch 00084: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-084-44.10.h5
#
# Epoch 00084: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 85/200
# 60000/60000 [==============================] - 211s 4ms/step - loss: 44.1249 - vae_r_loss: 38.6968 - vae_kl_loss: 5.4280
#
# Epoch 00085: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-085-44.12.h5
#
# Epoch 00085: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 86/200
# 60000/60000 [==============================] - 212s 4ms/step - loss: 44.1086 - vae_r_loss: 38.6908 - vae_kl_loss: 5.4178
#
# Epoch 00086: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-086-44.11.h5
#
# Epoch 00086: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 87/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 44.0747 - vae_r_loss: 38.6526 - vae_kl_loss: 5.4221
#
# Epoch 00087: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-087-44.07.h5
#
# Epoch 00087: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 88/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 44.0849 - vae_r_loss: 38.6503 - vae_kl_loss: 5.4346
#
# Epoch 00088: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-088-44.08.h5
#
# Epoch 00088: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 89/200
# 60000/60000 [==============================] - 216s 4ms/step - loss: 44.0695 - vae_r_loss: 38.6292 - vae_kl_loss: 5.4403
#
# Epoch 00089: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-089-44.07.h5
#
# Epoch 00089: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 90/200
# 60000/60000 [==============================] - 210s 3ms/step - loss: 43.9910 - vae_r_loss: 38.5474 - vae_kl_loss: 5.4436
#
# Epoch 00090: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-090-43.99.h5
#
# Epoch 00090: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 91/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 44.0236 - vae_r_loss: 38.5752 - vae_kl_loss: 5.4484
#
# Epoch 00091: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-091-44.02.h5
#
# Epoch 00091: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 92/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 44.0233 - vae_r_loss: 38.5882 - vae_kl_loss: 5.4351
#
# Epoch 00092: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-092-44.02.h5
#
# Epoch 00092: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 93/200
# 60000/60000 [==============================] - 214s 4ms/step - loss: 43.9936 - vae_r_loss: 38.5363 - vae_kl_loss: 5.4573
#
# Epoch 00093: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-093-43.99.h5
#
# Epoch 00093: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 94/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 43.9730 - vae_r_loss: 38.5269 - vae_kl_loss: 5.4461
#
# Epoch 00094: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-094-43.97.h5
#
# Epoch 00094: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 95/200
# 60000/60000 [==============================] - 212s 4ms/step - loss: 43.9755 - vae_r_loss: 38.5226 - vae_kl_loss: 5.4529
#
# Epoch 00095: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-095-43.98.h5
#
# Epoch 00095: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 96/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 43.9493 - vae_r_loss: 38.4923 - vae_kl_loss: 5.4570
#
# Epoch 00096: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-096-43.95.h5
#
# Epoch 00096: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 97/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 43.9729 - vae_r_loss: 38.5147 - vae_kl_loss: 5.4582
#
# Epoch 00097: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-097-43.97.h5
#
# Epoch 00097: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 98/200
# 60000/60000 [==============================] - 227s 4ms/step - loss: 43.9732 - vae_r_loss: 38.5058 - vae_kl_loss: 5.4674
#
# Epoch 00098: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-098-43.97.h5
#
# Epoch 00098: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 99/200
# 60000/60000 [==============================] - 228s 4ms/step - loss: 43.9409 - vae_r_loss: 38.4836 - vae_kl_loss: 5.4573
#
# Epoch 00099: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-099-43.94.h5
#
# Epoch 00099: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 100/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 43.9107 - vae_r_loss: 38.4616 - vae_kl_loss: 5.4491
#
# Epoch 00100: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-100-43.91.h5
#
# Epoch 00100: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 101/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 43.8863 - vae_r_loss: 38.4260 - vae_kl_loss: 5.4603
#
# Epoch 00101: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-101-43.89.h5
#
# Epoch 00101: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 102/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 43.8596 - vae_r_loss: 38.4024 - vae_kl_loss: 5.4573
#
# Epoch 00102: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-102-43.86.h5
#
# Epoch 00102: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 103/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 43.9527 - vae_r_loss: 38.4954 - vae_kl_loss: 5.4573
#
# Epoch 00103: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-103-43.95.h5
#
# Epoch 00103: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 104/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 43.8270 - vae_r_loss: 38.3477 - vae_kl_loss: 5.4794
#
# Epoch 00104: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-104-43.83.h5
#
# Epoch 00104: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 105/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 43.8358 - vae_r_loss: 38.3611 - vae_kl_loss: 5.4747
#
# Epoch 00105: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-105-43.84.h5
#
# Epoch 00105: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 106/200
# 60000/60000 [==============================] - 209s 3ms/step - loss: 43.8638 - vae_r_loss: 38.3914 - vae_kl_loss: 5.4724
#
# Epoch 00106: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-106-43.86.h5
#
# Epoch 00106: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 107/200
# 60000/60000 [==============================] - 214s 4ms/step - loss: 43.8260 - vae_r_loss: 38.3585 - vae_kl_loss: 5.4675
#
# Epoch 00107: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-107-43.83.h5
#
# Epoch 00107: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 108/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 43.8329 - vae_r_loss: 38.3541 - vae_kl_loss: 5.4787
#
# Epoch 00108: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-108-43.83.h5
#
# Epoch 00108: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 109/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 43.7883 - vae_r_loss: 38.3013 - vae_kl_loss: 5.4869
#
# Epoch 00109: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-109-43.79.h5
#
# Epoch 00109: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 110/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 43.8106 - vae_r_loss: 38.3210 - vae_kl_loss: 5.4897
#
# Epoch 00110: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-110-43.81.h5
#
# Epoch 00110: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 111/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 43.8005 - vae_r_loss: 38.3193 - vae_kl_loss: 5.4812
#
# Epoch 00111: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-111-43.80.h5
#
# Epoch 00111: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 112/200
# 60000/60000 [==============================] - 210s 4ms/step - loss: 43.8132 - vae_r_loss: 38.3241 - vae_kl_loss: 5.4892
#
# Epoch 00112: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-112-43.81.h5
#
# Epoch 00112: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 113/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 43.7895 - vae_r_loss: 38.2876 - vae_kl_loss: 5.5020
#
# Epoch 00113: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-113-43.79.h5
#
# Epoch 00113: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 114/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 43.7899 - vae_r_loss: 38.2915 - vae_kl_loss: 5.4985
#
# Epoch 00114: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-114-43.79.h5
#
# Epoch 00114: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 115/200
# 60000/60000 [==============================] - 216s 4ms/step - loss: 43.7383 - vae_r_loss: 38.2465 - vae_kl_loss: 5.4918
#
# Epoch 00115: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-115-43.74.h5
#
# Epoch 00115: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 116/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 43.7462 - vae_r_loss: 38.2652 - vae_kl_loss: 5.4810
#
# Epoch 00116: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-116-43.75.h5
#
# ...
# Epoch 160/200
# 60000/60000 [==============================] - 209s 3ms/step - loss: 43.4263 - vae_r_loss: 37.8721 - vae_kl_loss: 5.5542
#
# Epoch 00160: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-160-43.43.h5
#
# Epoch 00160: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 161/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 43.4634 - vae_r_loss: 37.9043 - vae_kl_loss: 5.5590
#
# Epoch 00161: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-161-43.46.h5
#
# Epoch 00161: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 162/200
# 60000/60000 [==============================] - 211s 4ms/step - loss: 43.4682 - vae_r_loss: 37.9124 - vae_kl_loss: 5.5557
#
# Epoch 00162: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-162-43.47.h5
#
# Epoch 00162: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 163/200
# 60000/60000 [==============================] - 211s 4ms/step - loss: 43.4049 - vae_r_loss: 37.8436 - vae_kl_loss: 5.5614
#
# Epoch 00163: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-163-43.40.h5
#
# Epoch 00163: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 164/200
# 60000/60000 [==============================] - 211s 4ms/step - loss: 43.3934 - vae_r_loss: 37.8242 - vae_kl_loss: 5.5693
#
# Epoch 00164: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-164-43.39.h5
#
# Epoch 00164: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 165/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 43.4270 - vae_r_loss: 37.8618 - vae_kl_loss: 5.5652
#
# Epoch 00165: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-165-43.43.h5
#
# Epoch 00165: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 166/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 43.3848 - vae_r_loss: 37.8283 - vae_kl_loss: 5.5565
#
# Epoch 00166: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-166-43.38.h5
#
# Epoch 00166: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 167/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 43.3648 - vae_r_loss: 37.7966 - vae_kl_loss: 5.5682
#
# Epoch 00167: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-167-43.36.h5
#
# Epoch 00167: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 168/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 43.4002 - vae_r_loss: 37.8304 - vae_kl_loss: 5.5698
#
# Epoch 00168: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-168-43.40.h5
#
# Epoch 00168: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 169/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 43.4102 - vae_r_loss: 37.8385 - vae_kl_loss: 5.5716
#
# Epoch 00169: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-169-43.41.h5
#
# Epoch 00169: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 170/200
# 60000/60000 [==============================] - 216s 4ms/step - loss: 43.3456 - vae_r_loss: 37.7804 - vae_kl_loss: 5.5652
#
# Epoch 00170: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-170-43.35.h5
#
# Epoch 00170: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 171/200
# 60000/60000 [==============================] - 214s 4ms/step - loss: 43.3818 - vae_r_loss: 37.7990 - vae_kl_loss: 5.5828
#
# Epoch 00171: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-171-43.38.h5
#
# Epoch 00171: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 172/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 43.4115 - vae_r_loss: 37.8415 - vae_kl_loss: 5.5699
#
# Epoch 00172: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-172-43.41.h5
#
# Epoch 00172: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 173/200
# 60000/60000 [==============================] - 216s 4ms/step - loss: 43.4108 - vae_r_loss: 37.8495 - vae_kl_loss: 5.5613
#
# Epoch 00173: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-173-43.41.h5
#
# Epoch 00173: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 174/200
# 60000/60000 [==============================] - 223s 4ms/step - loss: 43.3767 - vae_r_loss: 37.8090 - vae_kl_loss: 5.5676
#
# Epoch 00174: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-174-43.38.h5
#
# Epoch 00174: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 175/200
# 60000/60000 [==============================] - 226s 4ms/step - loss: 43.3397 - vae_r_loss: 37.7798 - vae_kl_loss: 5.5599
#
# Epoch 00175: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-175-43.34.h5
#
# Epoch 00175: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 176/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 43.3432 - vae_r_loss: 37.7633 - vae_kl_loss: 5.5799
#
# Epoch 00176: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-176-43.34.h5
#
# Epoch 00176: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 177/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 43.5199 - vae_r_loss: 37.9633 - vae_kl_loss: 5.5566
#
# Epoch 00177: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-177-43.52.h5
#
# Epoch 00177: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 178/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 43.3819 - vae_r_loss: 37.8134 - vae_kl_loss: 5.5685
#
# Epoch 00178: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-178-43.38.h5
#
# Epoch 00178: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 179/200
# 60000/60000 [==============================] - 214s 4ms/step - loss: 43.3351 - vae_r_loss: 37.7535 - vae_kl_loss: 5.5816
#
# Epoch 00179: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-179-43.34.h5
#
# Epoch 00179: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 180/200
# 60000/60000 [==============================] - 222s 4ms/step - loss: 43.3728 - vae_r_loss: 37.8047 - vae_kl_loss: 5.5681
#
# Epoch 00180: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-180-43.37.h5
#
# Epoch 00180: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 181/200
# 60000/60000 [==============================] - 221s 4ms/step - loss: 43.3162 - vae_r_loss: 37.7366 - vae_kl_loss: 5.5797
#
# Epoch 00181: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-181-43.32.h5
#
# Epoch 00181: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 182/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 43.3490 - vae_r_loss: 37.7494 - vae_kl_loss: 5.5997
#
# Epoch 00182: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-182-43.35.h5
#
# Epoch 00182: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 183/200
# 60000/60000 [==============================] - 222s 4ms/step - loss: 43.2941 - vae_r_loss: 37.7067 - vae_kl_loss: 5.5875
#
# Epoch 00183: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-183-43.29.h5
#
# Epoch 00183: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 184/200
# 60000/60000 [==============================] - 219s 4ms/step - loss: 43.3365 - vae_r_loss: 37.7586 - vae_kl_loss: 5.5779
#
# Epoch 00184: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-184-43.34.h5
#
# Epoch 00184: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 185/200
# 60000/60000 [==============================] - 216s 4ms/step - loss: 43.3333 - vae_r_loss: 37.7457 - vae_kl_loss: 5.5876
#
# Epoch 00185: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-185-43.33.h5
#
# Epoch 00185: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 186/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 43.3288 - vae_r_loss: 37.7392 - vae_kl_loss: 5.5896
#
# Epoch 00186: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-186-43.33.h5
#
# Epoch 00186: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 187/200
# 60000/60000 [==============================] - 214s 4ms/step - loss: 43.2687 - vae_r_loss: 37.6793 - vae_kl_loss: 5.5894
#
# Epoch 00187: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-187-43.27.h5
#
# Epoch 00187: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 188/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 43.3126 - vae_r_loss: 37.7154 - vae_kl_loss: 5.5972
#
# Epoch 00188: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-188-43.31.h5
#
# Epoch 00188: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 189/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 43.3141 - vae_r_loss: 37.7225 - vae_kl_loss: 5.5917
#
# Epoch 00189: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-189-43.31.h5
#
# Epoch 00189: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 190/200
# 60000/60000 [==============================] - 214s 4ms/step - loss: 43.2700 - vae_r_loss: 37.6897 - vae_kl_loss: 5.5804
#
# Epoch 00190: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-190-43.27.h5
#
# Epoch 00190: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 191/200
# 60000/60000 [==============================] - 211s 4ms/step - loss: 43.3205 - vae_r_loss: 37.7376 - vae_kl_loss: 5.5829
#
# Epoch 00191: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-191-43.32.h5
#
# Epoch 00191: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 192/200
# 60000/60000 [==============================] - 213s 4ms/step - loss: 43.2324 - vae_r_loss: 37.6464 - vae_kl_loss: 5.5861
#
# Epoch 00192: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-192-43.23.h5
#
# Epoch 00192: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 193/200
# 60000/60000 [==============================] - 212s 4ms/step - loss: 43.3164 - vae_r_loss: 37.7262 - vae_kl_loss: 5.5901
#
# Epoch 00193: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-193-43.32.h5
#
# Epoch 00193: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 194/200
# 60000/60000 [==============================] - 215s 4ms/step - loss: 43.2427 - vae_r_loss: 37.6510 - vae_kl_loss: 5.5916
#
# Epoch 00194: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-194-43.24.h5
#
# Epoch 00194: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 195/200
# 60000/60000 [==============================] - 218s 4ms/step - loss: 43.2247 - vae_r_loss: 37.6337 - vae_kl_loss: 5.5910
#
# Epoch 00195: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-195-43.22.h5
#
# Epoch 00195: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 196/200
# 60000/60000 [==============================] - 211s 4ms/step - loss: 43.2381 - vae_r_loss: 37.6481 - vae_kl_loss: 5.5900
#
# Epoch 00196: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-196-43.24.h5
#
# Epoch 00196: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 197/200
# 60000/60000 [==============================] - 217s 4ms/step - loss: 43.2969 - vae_r_loss: 37.7097 - vae_kl_loss: 5.5871
#
# Epoch 00197: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights-197-43.30.h5
#
# Epoch 00197: saving model to /content/gdrive/My Drive/Colab Notebooks/Generative Deep Learning/run/vae/0002_digits/weights/weights.h5
# Epoch 198/200
# 27232/60000 [============>.................] - ETA: 1:56 - loss: 43.1873 - vae_r_loss: 37.5830 - vae_kl_loss: 5.6042

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.stats import norm

# %%
n_to_show = 10
np.random.seed(88)
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]

z_points = vae.encoder.predict(example_images)

reconst_images = vae.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+1)
    sub.axis('off')
    sub.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=sub.transAxes)
            
    sub.imshow(img, cmap='gray_r')

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    sub.axis('off')
    sub.imshow(img, cmap='gray_r')

# %%
n_to_show = 5000
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)
plt.show()

# %%
figsize = 10
plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)


grid_size = 15
grid_depth = 2
figsize = 15

x = np.random.normal(size = grid_size * grid_depth)
y = np.random.normal(size = grid_size * grid_depth)

z_grid = np.array(list(zip(x, y)))
reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=8, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %%
n_to_show = 5000
grid_size = 15
fig_height = 7
fig_width = 15

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)
p_points = norm.cdf(z_points)

fig = plt.figure(figsize=(fig_width, fig_height))

ax = fig.add_subplot(1, 2, 1)
plot_1 = ax.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c=example_labels
            , alpha=0.5, s=2)
plt.colorbar(plot_1)

ax = fig.add_subplot(1, 2, 2)
plot_2 = ax.scatter(p_points[:, 0] , p_points[:, 1] , cmap='rainbow' , c=example_labels
            , alpha=0.5, s=5)

plt.show()
